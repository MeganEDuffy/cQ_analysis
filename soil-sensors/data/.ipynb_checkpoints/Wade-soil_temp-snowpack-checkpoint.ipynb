# %%
# Ranch Brook WY2023 TMS-4 Soil Data
# from Garnet Williams 2025-02-12
# modified MED 2025-02-13
# MED commented out all transects except best Wade analog, SML1; similar elevation

################################################################################
# Load Packages and Data
if (!require("pacman")) install.packages("pacman")
library(pacman)
p_load(readxl, dplyr,ggplot2, knitr, patchwork, tidyr, lubridate, gridExtra)

# Define the directory path where the data files are stored
directory_path <- "~//OneDrive/git-repos//cQ_analysis/soil-sensors/data//Ranch_Brook/Ranch-Brook-WY23-TMS4/2023_TMS4_Data/2023_TMS4_Data/"
output_path <- "~//OneDrive/git-repos//cQ_analysis/soil-sensors/data//Ranch_Brook/Ranch-Brook-WY23-TMS4/figures/"

# Read in snowpack data
snow_directory_path <- "~//OneDrive//git-repos/cQ_analysis/snowpack/data/"

snow_mans <- read.csv("~//OneDrive/git-repos/cQ_analysis/snowpack/data/mansfield-noaa-WY22-WY23-3855342.csv")
snow_mans$DATE <- as.POSIXct(snow_mans$date, format = "%Y/%m/%d")

file_path <- paste0(directory_path, "data_95224", probe_number, "_2023_05_07_0.csv")
# Define the probe numbers range for each transect
transects <- list(
  "SML1" = 301:304#,
  #"SML2" = 305:308,
  #"Bear_Run_Low" = 309:312,
  #"Bear_Run_2" = 313:316,
  #"Bear_Run_1_Low" = 317:320,
  #"Bear_Run_1_High" = 321:324,
  #"Bruce_Trail" = 325:328
)

# Define the date range for filtering
start_date <- as.POSIXct("2023-02-01", format = "%Y-%m-%d", tz = "UTC")
end_date <- as.POSIXct("2023-04-30", format = "%Y-%m-%d", tz = "UTC")

# Initialize a list to store dataframes for each transect
transect_data <- list()

# Loop through each transect
for (transect_name in names(transects)) {
  # Initialize an empty list to store dataframes for the current transect
  transect_dataframes <- list()
  # Loop through each probe number in the current transect
  for (probe_number in transects[[transect_name]]) {
    # Generate the file path
    file_path <- paste0(directory_path, "data_95224", probe_number, "_2023_05_07_0.csv")
    # Read data
    tms_data <- read.table(file_path, header = FALSE, sep = ";", dec = ",")
    # Assign column names
    names(tms_data) <- c("row", "dateTimeText", "timeZone", "Soil_temp", "temperature2", "Air_temp", "moisturecounts", "shake", "ErrFlag", "col10")
    # Convert dateTime and date columns to POSIX format
    tms_data$dateTime <- strptime(tms_data$dateTimeText, "%Y.%m.%d %H:%M", tz = "UTC")
    tms_data$date <- strptime(tms_data$dateTimeText, "%Y.%m.%d", tz = "UTC")
    # Make tibble
    tms_df <- as_tibble(tms_data)
    # Add a column for ggplot
    tms_df$dateTime2 <- as.POSIXct(tms_df$dateTime, format = "%m/%d/%Y %H:%M")
    # Add a column for VWC
    tms_df$VWC <- (0.0000000009 * (tms_df$moisturecounts^2) + (0.000262 * tms_df$moisturecounts) - 0.159)
    # Add a column for TMS_ID with correct levels
    tms_df$TMS_ID <- factor(probe_number - min(transects[[transect_name]]) + 1, levels = 1:length(transects[[transect_name]]))
    # Store the dataframe in the list
    transect_dataframes[[probe_number]] <- tms_df
  }
  # Combine the dataframes into a single dataframe for the current transect
  transect_combined <- bind_rows(transect_dataframes)
  # Store the combined dataframe in the transect_data list
  transect_data[[transect_name]] <- transect_combined
}
# Out:
# Error in `$<-.data.frame`(`*tmp*`, DATE, value = structure(numeric(0), class = c("POSIXct", : replacement has 0 rows, data has 730
# Traceback:
#
# 1. `$<-.data.frame`(`*tmp*`, DATE, value = structure(numeric(0), class = c("POSIXct",
#  . "POSIXt"), tzone = ""))
# 2. stop(sprintf(ngettext(N, "replacement has %d row, data has %d",
#  .     "replacement has %d rows, data has %d"), N, nrows), domain = NA)
# 3. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "replacement has 0 rows, data has 730", base::quote(`$<-.data.frame`(`*tmp*`,
#  .     DATE, value = structure(numeric(0), class = c("POSIXct",
#  .     "POSIXt"), tzone = ""))))

# %%
snow_mans
# Out:
#     STATION     NAME                   DATE       PRCP SNWD TMAX TMIN TOBS
# 1   USC00435416 MOUNT MANSFIELD, VT US 2021-10-01 0.00  0   46   39   43
# 2   USC00435416 MOUNT MANSFIELD, VT US 2021-10-02 0.48  0   51   41   50
# 3   USC00435416 MOUNT MANSFIELD, VT US 2021-10-03 0.12  0   53   50   51
# 4   USC00435416 MOUNT MANSFIELD, VT US 2021-10-04 0.00  0   53   46   46
# 5   USC00435416 MOUNT MANSFIELD, VT US 2021-10-05 0.04  0   56   44   54
# 6   USC00435416 MOUNT MANSFIELD, VT US 2021-10-06 0.00  0   58   50   56
# 7   USC00435416 MOUNT MANSFIELD, VT US 2021-10-07 0.00  0   60   50   56
# 8   USC00435416 MOUNT MANSFIELD, VT US 2021-10-08 0.00  0   64   49   61
# 9   USC00435416 MOUNT MANSFIELD, VT US 2021-10-09 0.00  0   61   43   48
# 10  USC00435416 MOUNT MANSFIELD, VT US 2021-10-10 0.00  0   54   44   51
# 11  USC00435416 MOUNT MANSFIELD, VT US 2021-10-11 0.01  0   62   48   61
# 12  USC00435416 MOUNT MANSFIELD, VT US 2021-10-12 0.00  0   69   54   66
# 13  USC00435416 MOUNT MANSFIELD, VT US 2021-10-13 0.00  0   66   55   60
# 14  USC00435416 MOUNT MANSFIELD, VT US 2021-10-14 0.20  0   61   55   55
# 15  USC00435416 MOUNT MANSFIELD, VT US 2021-10-15 0.02 NA   62   53   60
# 16  USC00435416 MOUNT MANSFIELD, VT US 2021-10-16 0.36  0   62   53   53
# 17  USC00435416 MOUNT MANSFIELD, VT US 2021-10-17 0.61  0   55   37   40
# 18  USC00435416 MOUNT MANSFIELD, VT US 2021-10-18 0.24 NA   42   33   33
# 19  USC00435416 MOUNT MANSFIELD, VT US 2021-10-19 0.33  1   34   31   33
# 20  USC00435416 MOUNT MANSFIELD, VT US 2021-10-20 0.00 NA   55   33   51
# 21  USC00435416 MOUNT MANSFIELD, VT US 2021-10-21 0.19 NA   54   46   49
# 22  USC00435416 MOUNT MANSFIELD, VT US 2021-10-22 0.13 NA   52   37   37
# 23  USC00435416 MOUNT MANSFIELD, VT US 2021-10-23 0.00  0   38   25   34
# 24  USC00435416 MOUNT MANSFIELD, VT US 2021-10-24 0.02  0   40   25   39
# 25  USC00435416 MOUNT MANSFIELD, VT US 2021-10-25 0.33 NA   39   32   34
# 26  USC00435416 MOUNT MANSFIELD, VT US 2021-10-26 0.12 NA   46   34   44
# 27  USC00435416 MOUNT MANSFIELD, VT US 2021-10-27 0.05  0   47   38   46
# 28  USC00435416 MOUNT MANSFIELD, VT US 2021-10-28 0.00 NA   48   35   45
# 29  USC00435416 MOUNT MANSFIELD, VT US 2021-10-29 0.00  0   51   34   47
# 30  USC00435416 MOUNT MANSFIELD, VT US 2021-10-30 0.13  0   47   32   43
# ⋮   ⋮           ⋮                      ⋮          ⋮    ⋮    ⋮    ⋮    ⋮
# 701 USC00435416 MOUNT MANSFIELD, VT US 2023-09-01 0.00 0    61   45   58
# 702 USC00435416 MOUNT MANSFIELD, VT US 2023-09-02   NA 0    69   50   60
# 703 USC00435416 MOUNT MANSFIELD, VT US 2023-09-03   NA 0    NA   NA   NA
# 704 USC00435416 MOUNT MANSFIELD, VT US 2023-09-04   NA 0    NA   NA   NA
# 705 USC00435416 MOUNT MANSFIELD, VT US 2023-09-05 0.00 0    NA   NA   NA
# 706 USC00435416 MOUNT MANSFIELD, VT US 2023-09-06 0.00 0    NA   NA   NA
# 707 USC00435416 MOUNT MANSFIELD, VT US 2023-09-07   NA 0    NA   NA   56
# 708 USC00435416 MOUNT MANSFIELD, VT US 2023-09-08 0.33 0    NA   NA   NA
# 709 USC00435416 MOUNT MANSFIELD, VT US 2023-09-09 0.10 0    65   51   60
# 710 USC00435416 MOUNT MANSFIELD, VT US 2023-09-10 0.27 0    NA   NA   59
# 711 USC00435416 MOUNT MANSFIELD, VT US 2023-09-11 0.06 0    62   56   57
# 712 USC00435416 MOUNT MANSFIELD, VT US 2023-09-12 0.02 0    76   54   61
# 713 USC00435416 MOUNT MANSFIELD, VT US 2023-09-13 0.04 0    61   54   55
# 714 USC00435416 MOUNT MANSFIELD, VT US 2023-09-14 0.24 0    62   44   NA
# 715 USC00435416 MOUNT MANSFIELD, VT US 2023-09-15 0.00 0    55   40   52
# 716 USC00435416 MOUNT MANSFIELD, VT US 2023-09-16 0.00 0    54   44   50
# 717 USC00435416 MOUNT MANSFIELD, VT US 2023-09-17 0.00 0    61   44   55
# 718 USC00435416 MOUNT MANSFIELD, VT US 2023-09-18 0.21 0    56   45   51
# 719 USC00435416 MOUNT MANSFIELD, VT US 2023-09-19 0.27 0    52   47   48
# 720 USC00435416 MOUNT MANSFIELD, VT US 2023-09-20 0.13 0    53   42   52
# 721 USC00435416 MOUNT MANSFIELD, VT US 2023-09-21 0.00 0    56   43   55
# 722 USC00435416 MOUNT MANSFIELD, VT US 2023-09-22 0.00 0    61   45   57
# 723 USC00435416 MOUNT MANSFIELD, VT US 2023-09-23 0.00 0    61   46   54
# 724 USC00435416 MOUNT MANSFIELD, VT US 2023-09-24 0.00 0    60   50   57
# 725 USC00435416 MOUNT MANSFIELD, VT US 2023-09-25 0.00 0    60   48   56
# 726 USC00435416 MOUNT MANSFIELD, VT US 2023-09-26 0.00 0    60   38   53
# 727 USC00435416 MOUNT MANSFIELD, VT US 2023-09-27 0.00 0    61   43   58
# 728 USC00435416 MOUNT MANSFIELD, VT US 2023-09-28 0.00 0    61   47   59
# 729 USC00435416 MOUNT MANSFIELD, VT US 2023-09-29 0.03 0    59   47   56
# 730 USC00435416 MOUNT MANSFIELD, VT US 2023-09-30 0.00 0    67   48   62
